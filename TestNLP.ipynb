# %%
import keras
import nltk
import pandas as pd
import numpy as np
import re
import codecs
# Out:
# Using TensorFlow backend.

# %%
id_column = "id"
missing_token = " UNK "

train = pd.read_csv("train.csv", parse_dates=["project_submitted_datetime"])
test = pd.read_csv("test.csv", parse_dates=["project_submitted_datetime"])
rc = pd.read_csv("resources.csv").fillna(missing_token)

df = pd.concat([train, test], axis=0, sort=False)
# Out:
# /Users/davidstroud/anaconda3/envs/snakes/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.describe()
# Out:
#        teacher_number_of_previously_posted_projects  project_is_approved
# count                                 260115.000000        182080.000000
# mean                                      11.248463             0.847682
# std                                       28.005731             0.359330
# min                                        0.000000             0.000000
# 25%                                        0.000000             1.000000
# 50%                                        2.000000             1.000000
# 75%                                        9.000000             1.000000
# max                                      451.000000             1.000000

# %%
from nltk.tokenize import RegexpTokenizer

tokenizer = RegexpTokenizer(r'\w+')

df["tokens"] = df["project_essay_1"].apply(tokenizer.tokenize)
df.head()
# Out:
#         id                        teacher_id teacher_prefix school_state  \
# 0  p036502  484aaf11257089a66cfedc9461c6bd0a            Ms.           NV
# 1  p039565  df72a3ba8089423fa8a94be88060f6ed           Mrs.           GA
# 2  p233823  a9b876a9252e08a55e3d894150f75ba3            Ms.           UT
# 3  p185307  525fdbb6ec7f538a48beebaa0a51b24f            Mr.           NC
# 4  p013780  a63b5547a7239eae4c1872670848e61a            Mr.           CA
#
#   project_submitted_datetime project_grade_category  \
# 0        2016-11-18 14:45:59          Grades PreK-2
# 1        2017-04-26 15:57:28             Grades 3-5
# 2        2017-01-01 22:57:44             Grades 3-5
# 3        2016-08-12 15:42:11             Grades 3-5
# 4        2016-08-06 09:09:11             Grades 6-8
#
#             project_subject_categories  \
# 0                  Literacy & Language
# 1    Music & The Arts, Health & Sports
# 2  Math & Science, Literacy & Language
# 3                      Health & Sports
# 4                      Health & Sports
#
#             project_subject_subcategories  \
# 0                                Literacy
# 1            Performing Arts, Team Sports
# 2  Applied Sciences, Literature & Writing
# 3                       Health & Wellness
# 4                       Health & Wellness
#
#                                        project_title  \
# 0                           Super Sight Word Centers
# 1                             Keep Calm and Dance On
# 2                              Lets 3Doodle to Learn
# 3  \"Kid Inspired\" Equipment to Increase Activit...
# 4   We need clean water for our culinary arts class!
#
#                                      project_essay_1  \
# 0  Most of my kindergarten students come from low...
# 1  Our elementary school is a culturally rich sch...
# 2  Hello;\r\nMy name is Mrs. Brotherton. I teach ...
# 3  My students are the greatest students but are ...
# 4  My students are athletes and students who are ...
#
#                                      project_essay_2 project_essay_3  \
# 0  I currently have a differentiated sight word c...             NaN
# 1  We strive to provide our diverse population of...             NaN
# 2  We are looking to add some 3Doodler to our cla...             NaN
# 3  The student's project which is totally \"kid-i...             NaN
# 4  For some reason in our kitchen the water comes...             NaN
#
#   project_essay_4                           project_resource_summary  \
# 0             NaN  My students need 6 Ipod Nano's to create and d...
# 1             NaN  My students need matching shirts to wear for d...
# 2             NaN  My students need the 3doodler. We are an SEM s...
# 3             NaN  My students need balls and other activity equi...
# 4             NaN  My students need a water filtration system for...
#
#    teacher_number_of_previously_posted_projects  project_is_approved  \
# 0                                            26                  1.0
# 1                                             1                  0.0
# 2                                             5                  1.0
# 3                                            16                  0.0
# 4                                            42                  1.0
#
#                                               tokens
# 0  [Most, of, my, kindergarten, students, come, f...
# 1  [Our, elementary, school, is, a, culturally, r...
# 2  [Hello, r, nMy, name, is, Mrs, Brotherton, I, ...
# 3  [My, students, are, the, greatest, students, b...
# 4  [My, students, are, athletes, and, students, w...

# %%
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

all_words = [word for tokens in df["tokens"] for word in tokens]
sentence_lengths = [len(tokens) for tokens in df["tokens"]]
VOCAB = sorted(list(set(all_words)))
print("%s words total, with a vocabulary size of %s" % (len(all_words), len(VOCAB)))
print("Max sentence length is %s" % max(sentence_lengths))
# Out:
# 30278063 words total, with a vocabulary size of 60234
# Max sentence length is 1342

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(10, 10)) 
plt.xlabel('Sentence length')
plt.ylabel('Number of sentences')
plt.hist(sentence_lengths)
plt.show()

# %%
df.groupby("project_is_approved").count()
# Out:
#                          id  teacher_id  teacher_prefix  school_state  \
# project_is_approved
# 0.0                   27734       27734           27734         27734
# 1.0                  154346      154346          154342        154346
#
#                      project_submitted_datetime  project_grade_category  \
# project_is_approved
# 0.0                                       27734                   27734
# 1.0                                      154346                  154346
#
#                      project_subject_categories  \
# project_is_approved
# 0.0                                       27734
# 1.0                                      154346
#
#                      project_subject_subcategories  project_title  \
# project_is_approved
# 0.0                                          27734          27734
# 1.0                                         154346         154346
#
#                      project_essay_1  project_essay_2  project_essay_3  \
# project_is_approved
# 0.0                            27734            27734              824
# 1.0                           154346           154346             5550
#
#                      project_essay_4  project_resource_summary  \
# project_is_approved
# 0.0                              824                     27734
# 1.0                             5550                    154346
#
#                      teacher_number_of_previously_posted_projects  tokens
# project_is_approved
# 0.0                                                         27734   27734
# 1.0                                                        154346  154346

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

def cv(data):
    count_vectorizer = CountVectorizer()

    emb = count_vectorizer.fit_transform(data)

    return emb, count_vectorizer

list_corpus = df["project_essay_1"].tolist()
list_labels = df["project_is_approved"].tolist()

X_train, X_test, y_train, y_test = train_test_split(list_corpus, list_labels, test_size=0.2, 
                                                                                random_state=40)

X_train_counts, count_vectorizer = cv(X_train)
X_test_counts = count_vectorizer.transform(X_test)

# %%
from sklearn.decomposition import PCA, TruncatedSVD
import matplotlib
import matplotlib.patches as mpatches


def plot_LSA(test_data, test_labels, savepath="PCA_demo.csv", plot=True):
        lsa = TruncatedSVD(n_components=2)
        lsa.fit(test_data)
        lsa_scores = lsa.transform(test_data)
        color_mapper = {label:idx for idx,label in enumerate(set(test_labels))}
        color_column = [color_mapper[label] for label in test_labels]
        colors = ['orange','blue','blue']
        if plot:
            plt.scatter(lsa_scores[:,0], lsa_scores[:,1], s=8, alpha=.8, c=test_labels, cmap=matplotlib.colors.ListedColormap(colors))
            red_patch = mpatches.Patch(color='orange', label='Irrelevant')
            green_patch = mpatches.Patch(color='blue', label='Disaster')
            plt.legend(handles=[red_patch, green_patch], prop={'size': 30})


fig = plt.figure(figsize=(16, 16))          
plot_LSA(X_train_counts, y_train)
plt.show()

# %%
get_text_stats(text_col='project_description')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-28aa556de2a2> in <module>()
# ----> 1 get_text_stats(text_col='project_description')
#
# NameError: name 'get_text_stats' is not defined
