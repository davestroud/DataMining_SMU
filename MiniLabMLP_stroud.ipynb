# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing import sequence, text
from keras.layers import Input, Embedding

from nltk import word_tokenize
from nltk.corpus import stopwords
from textblob import TextBlob

import datetime as dt
import pandas as pd
import numpy as np
import warnings
import string

# stop_words = []
stop_words = list(set(stopwords.words('english')))
warnings.filterwarnings('ignore')
punctuation = string.punctuation
# Out:
# Using TensorFlow backend.

# %%
id_column = "id"
missing_token = " UNK "

train = pd.read_csv("train.csv", parse_dates=["project_submitted_datetime"])
test = pd.read_csv("test.csv", parse_dates=["project_submitted_datetime"])
rc = pd.read_csv("resources.csv").fillna(missing_token)

df = pd.concat([train, test], axis=0)

# %%
df.head()
# Out:
#         id                                    project_essay_1  \
# 0  p036502  Most of my kindergarten students come from low...
# 1  p039565  Our elementary school is a culturally rich sch...
# 2  p233823  Hello;\r\nMy name is Mrs. Brotherton. I teach ...
# 3  p185307  My students are the greatest students but are ...
# 4  p013780  My students are athletes and students who are ...
#
#                                      project_essay_2 project_essay_3  \
# 0  I currently have a differentiated sight word c...             NaN
# 1  We strive to provide our diverse population of...             NaN
# 2  We are looking to add some 3Doodler to our cla...             NaN
# 3  The student's project which is totally \"kid-i...             NaN
# 4  For some reason in our kitchen the water comes...             NaN
#
#   project_essay_4 project_grade_category  project_is_approved  \
# 0             NaN          Grades PreK-2                  1.0
# 1             NaN             Grades 3-5                  0.0
# 2             NaN             Grades 3-5                  1.0
# 3             NaN             Grades 3-5                  0.0
# 4             NaN             Grades 6-8                  1.0
#
#                             project_resource_summary  \
# 0  My students need 6 Ipod Nano's to create and d...
# 1  My students need matching shirts to wear for d...
# 2  My students need the 3doodler. We are an SEM s...
# 3  My students need balls and other activity equi...
# 4  My students need a water filtration system for...
#
#             project_subject_categories  \
# 0                  Literacy & Language
# 1    Music & The Arts, Health & Sports
# 2  Math & Science, Literacy & Language
# 3                      Health & Sports
# 4                      Health & Sports
#
#             project_subject_subcategories project_submitted_datetime  \
# 0                                Literacy        2016-11-18 14:45:59
# 1            Performing Arts, Team Sports        2017-04-26 15:57:28
# 2  Applied Sciences, Literature & Writing        2017-01-01 22:57:44
# 3                       Health & Wellness        2016-08-12 15:42:11
# 4                       Health & Wellness        2016-08-06 09:09:11
#
#                                        project_title school_state  \
# 0                           Super Sight Word Centers           NV
# 1                             Keep Calm and Dance On           GA
# 2                              Lets 3Doodle to Learn           UT
# 3  \"Kid Inspired\" Equipment to Increase Activit...           NC
# 4   We need clean water for our culinary arts class!           CA
#
#                          teacher_id  \
# 0  484aaf11257089a66cfedc9461c6bd0a
# 1  df72a3ba8089423fa8a94be88060f6ed
# 2  a9b876a9252e08a55e3d894150f75ba3
# 3  525fdbb6ec7f538a48beebaa0a51b24f
# 4  a63b5547a7239eae4c1872670848e61a
#
#    teacher_number_of_previously_posted_projects teacher_prefix
# 0                                            26            Ms.
# 1                                             1           Mrs.
# 2                                             5            Ms.
# 3                                            16            Mr.
# 4                                            42            Mr.

# %%
# fillup empty values with missing token 
df['project_essay_3'] = df['project_essay_3'].fillna(missing_token)
df['project_essay_4'] = df['project_essay_4'].fillna(missing_token)

# extract length of each essay and title
df["essay1_len"] = df['project_essay_1'].apply(len)
df["essay2_len"] = df['project_essay_2'].apply(len)
df["essay3_len"] = df['project_essay_3'].apply(len)
df["essay4_len"] = df['project_essay_4'].apply(len)
df["title_len"] = df['project_title'].apply(len)

# %%
df[['essay1_len', 'essay2_len', 'essay3_len', 'essay4_len', 'title_len']].head(10)
# Out:
#    essay1_len  essay2_len  essay3_len  essay4_len  title_len
# 0         967         805           5           5         24
# 1         587         639           5           5         22
# 2         761         546           5           5         21
# 3        1201        1209           5           5         72
# 4         451         556           5           5         48
# 5         492         737           5           5         37
# 6         789         931           5           5         21
# 7         458         629           5           5         36
# 8         573         774           5           5         37
# 9         624         710           5           5         27

# %%
# combine the project essays to create a complete essay text
df['text'] = df.apply(lambda row: ' '.join([str(row['project_essay_1']), 
                                            str(row['project_essay_2']), 
                                            str(row['project_essay_3']), 
                                            str(row['project_essay_4'])]), axis=1)

# extract features from text
df['char_count'] = df['text'].apply(len)
df['word_count'] = df['text'].apply(lambda x: len(x.split()))
df['word_density'] = df['char_count'] / (df['word_count']+1)
df['punctuation_count'] = df['text'].apply(lambda x: len("".join(_ for _ in x if _ in punctuation))) 
df['title_word_count'] = df['text'].apply(lambda x: len([wrd for wrd in x.split() if wrd.istitle()]))
df['upper_case_word_count'] = df['text'].apply(lambda x: len([wrd for wrd in x.split() if wrd.isupper()]))
df['stopword_count'] = df['text'].apply(lambda x: len([wrd for wrd in x.split() if wrd.lower() in stop_words]))

# %%
df[['char_count', 'word_count', 'word_density', 'punctuation_count', 'title_word_count', 'upper_case_word_count', 'stopword_count']].head(10)
# Out:
#    char_count  word_count  word_density  punctuation_count  title_word_count  \
# 0        1785         314      5.666667                 40                21
# 1        1239         192      6.419689                 38                15
# 2        1320         236      5.569620                 26                26
# 3        2423         388      6.228792                 77                31
# 4        1020         187      5.425532                 15                13
# 5        1242         194      6.369231                 54                21
# 6        1733         282      6.123675                 43                23
# 7        1100         184      5.945946                 45                16
# 8        1360         239      5.666667                 31                11
# 9        1347         240      5.589212                 36                16
#
#    upper_case_word_count  stopword_count
# 0                      7             151
# 1                      5              79
# 2                      6             103
# 3                      6             188
# 4                      2              98
# 5                      5              88
# 6                      5             127
# 7                      2              75
# 8                      6             111
# 9                     10             114

# %%
temp=df.groupby('project_title')['project_is_approved'].agg(['sum','count'])
temp['approval_rate']=(temp['sum']*100)/temp['count']
temp.columns=['# of projects approved','# of total projects','Approval rate']
temp=temp.sort_values(by='# of total projects',ascending=False)
temp=temp.iloc[0:20]
temp
# Out:
#                               # of projects approved  # of total projects  \
# project_title
# Flexible Seating                               298.0                  377
# Wiggle While You Work                          137.0                  150
# Wiggle While We Work                           136.0                  149
# Can You Hear Me Now?                           135.0                  144
# Wiggle While You Work!                         122.0                  134
# Wiggle While We Work!                          116.0                  123
# We Like to Move It, Move It!                    85.0                  100
# Listen Up!                                      77.0                   83
# Technology in the Classroom                     69.0                   79
# Full STEAM Ahead!                               57.0                   74
# Alternative Seating                             58.0                   71
# Let's Get Moving!                               54.0                   68
# Classroom Supplies                              41.0                   67
# Classroom Library                               51.0                   56
# Let's Get Organized!                            44.0                   51
# Supplies for Success                            36.0                   50
# Flexible Seating!                               40.0                   50
# Wobble While You Work                           47.0                   49
# Wobble While We Work!                           46.0                   49
# Read All About It!                              42.0                   46
#
#                               Approval rate
# project_title
# Flexible Seating                  79.045093
# Wiggle While You Work             91.333333
# Wiggle While We Work              91.275168
# Can You Hear Me Now?              93.750000
# Wiggle While You Work!            91.044776
# Wiggle While We Work!             94.308943
# We Like to Move It, Move It!      85.000000
# Listen Up!                        92.771084
# Technology in the Classroom       87.341772
# Full STEAM Ahead!                 77.027027
# Alternative Seating               81.690141
# Let's Get Moving!                 79.411765
# Classroom Supplies                61.194030
# Classroom Library                 91.071429
# Let's Get Organized!              86.274510
# Supplies for Success              72.000000
# Flexible Seating!                 80.000000
# Wobble While You Work             95.918367
# Wobble While We Work!             93.877551
# Read All About It!                91.304348
